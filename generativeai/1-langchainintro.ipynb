# %% [markdown]
# ### langchain version v1

# %%
import langchain 
print(langchain.__version__)
# Out:
# 1.2.3

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GEMINI_KEY")

# %% [markdown]
# ### Generative Ai application using agents and open Ai models

# %%
from langchain.chat_models import  init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x000001CBB1F0B620>, default_metadata=(), model_kwargs={})

# %% [markdown]
# ### first Generative Ai Application

# %%
response = model.invoke("Hello, how are you?")
response.content
# Out:
# 'Hello! I am a large language model, trained by Google. I am functioning as expected and ready to assist you. How can I help you today?'
