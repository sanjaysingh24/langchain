# %% [markdown]
# ### Tools
# why we need tools (so in llm there are a training cut on the models in simple language we can say that the model are trained a  specific date or year than for example if the model was trained till the oct 2025 and i ask the input to the llm for the latest ai news in nov and dec 2025 than at that time llm are not trained over the data nov 2025 and dec 2025 but llm  create a output or  hallustion which is not that much accurate) so here we introduce the tools when i give the input of the current news in ai of dec 2025 then what it will do first it goes to the llm and check which tool i should use for this if the tool is present  then call this particular tool and  take some context from the tool and when llm recieve the context then it will add the prompt to the context and generate the output to the user
#
# models can request to call a tools that perform task such as  fetching data from database ,searching web, and running code tools are pairing of:
# 1- a schema, including the name  of the tool, a description, and/or argument definition(often  a Json Schema)
# 2- a function or  coroutine to excute

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"] = os.getenv("GEMINI_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.stream("write me an essay of ai")
for r in response:
    print(r.text,end="",flush=True)
# Out:
# ## The Algorithm's Ascent: Navigating the Dawn of Artificial Intelligence
#
# We stand at the precipice of a new era, one defined not by the discovery of new continents or the harnessing of new energies, but by the burgeoning intelligence that we ourselves are creating. Artificial Intelligence (AI), once a distant whisper in the realm of science fiction, is now a tangible force, weaving its way into the fabric of our daily lives. From the personalized recommendations that curate our digital experiences to the sophisticated algorithms driving medical diagnoses, AI’s ascent is undeniable, prompting both awe and apprehension as we grapple with its profound implications for humanity.
#
# At its core, AI represents the aspiration to imbue machines with the capacity for human-like cognition. This encompasses a spectrum of abilities, from learning and problem-solving to perception and decision-making. Early AI, characterized by rule-based systems and expert knowledge, laid the groundwork for what we see today. However, the true revolution has been fueled by advancements in machine learning, particularly deep learning. By enabling systems to learn from vast datasets without explicit programming, these neural networks have unlocked unprecedented capabilities, allowing AI to excel in tasks that were once considered exclusively human domains. Image recognition, natural language processing, and even creative endeavors like generating art and music are now within AI's purview, blurring the lines between human and machine ingenuity.
#
# The transformative potential of AI is vast and multifaceted. In healthcare, AI promises to revolutionize diagnostics, drug discovery, and personalized treatment plans, leading to more accurate and efficient patient care. In transportation, autonomous vehicles hold the potential to drastically reduce accidents and optimize traffic flow. The economic landscape is also being reshaped, with AI driving automation, enhancing productivity, and creating new industries. Beyond these practical applications, AI can serve as a powerful tool for scientific research, accelerating our understanding of complex phenomena and pushing the boundaries of human knowledge. It offers the tantalizing prospect of solving some of the world's most pressing challenges, from climate change to poverty, by processing information and identifying solutions at a scale and speed far beyond human capacity.
#
# However, with such immense power comes significant responsibility and a constellation of ethical and societal concerns. The most immediate worry revolves around job displacement. As AI-powered automation becomes more prevalent, many jobs, particularly those involving repetitive tasks, are at risk of becoming obsolete. This necessitates a proactive approach to reskilling and upskilling the workforce, fostering adaptability, and exploring new economic models that can accommodate a future where human labor may be redefined. Furthermore, the inherent biases present in the data used to train AI systems can perpetuate and even amplify existing societal inequalities, leading to discriminatory outcomes in areas like hiring, lending, and criminal justice. Ensuring fairness and transparency in AI development is paramount to preventing the entrenchment of prejudice.
#
# Beyond these practical considerations lie deeper philosophical questions. As AI systems become more sophisticated, questions of consciousness, sentience, and the very definition of intelligence come to the fore. What does it mean to be intelligent, and can a machine truly possess it? The potential for superintelligence, an AI that surpasses human intellect across all domains, raises existential questions about control and alignment. How do we ensure that such powerful entities remain benevolent and aligned with human values? The development of robust ethical frameworks, international cooperation, and ongoing public discourse are crucial to navigating these complex ethical landscapes and ensuring that AI's trajectory is guided by wisdom and foresight.
#
# The journey of AI is not a predetermined path but a collaborative endeavor. It is a testament to human curiosity and our relentless pursuit of progress. As we continue to push the boundaries of what is possible, we must do so with a profound sense of awareness and a commitment to responsible innovation. The algorithm's ascent is not just about building smarter machines; it is about understanding ourselves, our values, and the future we wish to create. By embracing collaboration, fostering critical thinking, and prioritizing ethical considerations, we can harness the transformative power of AI to build a future that is not only technologically advanced but also more equitable, prosperous, and ultimately, more human.

# %%
#tools
from langchain.tools import tool

@tool
def get_weather(location:str)->str:
    """Get the weather at a location"""
    return f"it's rainy in {location}"

model_with_tool = model.bind_tools([get_weather]) #binding the tool with the model

# %%
response = model_with_tool.invoke("What's the weather in Bangalore")
response.tool_calls
# Out:
# [{'name': 'get_weather',
#   'args': {'location': 'Bangalore'},
#   'id': '6a988eb6-0d6f-456f-a335-9265c72a0cc6',
#   'type': 'tool_call'}]

# %% [markdown]
# ### Tool Execution Loop

# %%
#step 1: model generates tool calls
message = [{"role":"user", "content":"what's the weather in Bangalore?"}]
ai_msg= model_with_tool.invoke(message)


message.append(ai_msg)

#step 2: Execute tools  and collect results
for tool_call in ai_msg.tool_calls:
    #execute the tool with the generated arguments
    tool_result = get_weather.invoke(tool_call)
    
    message.append(tool_result)


final_response = model_with_tool.invoke(message)
print(final_response.text)
# Out:
# The weather in Bangalore is rainy.

# %%
message
# Out:
# [{'role': 'user', 'content': "what's the weather in Bangalore?"},
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"location": "Bangalore"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bf8c8-7e0f-7e42-a87b-c97713537b61-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Bangalore'}, 'id': 'a8cd77d4-7486-40fc-8d5d-4530ebcf7cf5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 16, 'total_tokens': 63, 'input_token_details': {'cache_read': 0}}),
#  ToolMessage(content="it's sunny in Bangalore", name='get_weather', tool_call_id='a8cd77d4-7486-40fc-8d5d-4530ebcf7cf5')]
